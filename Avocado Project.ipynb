# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Desktop/avocado.csv') # Importing the data set

# %%
data.head() # Probing the data
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# These are the column names

# %%
data.shape
# Out:
# (18249, 14)

# %% [markdown]
# We have 18,249 rows and 14 columns

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# We have no null values

# %%
plt.figure(figsize=(14,12))
sns.heatmap(data.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# This is the co-relation heatmap, we can observe that none of the attributes are highly co-related to our target valiable, i.e. average price.

# %%
data.year.unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %% [markdown]
# Checking which years data we have. year 2015-2018

# %%
data.type.unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %% [markdown]
# We have two types of avocados, conventional and organic.

# %%
data.region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %% [markdown]
# Cities included in out data set.

# %%
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# Checking basic statistics of our data.

# %%
data.rename(columns={'4046':'PLU_4046', '4225':'PLU_4225','4770':'PLU_4770'}, inplace=True)

# %% [markdown]
# I am going to rename the PLU codes with the prefix PLU_ to make it more readable for people.

# %%
for col in data.select_dtypes(include=['float64','int64']):
    plt.figure()
    sns.displot(data[col],kind='kde',height=3)
    plt.show()

# %% [markdown]
# Performing bi variate aanalysis.

# %%
f,ax1 = plt.subplots(figsize = (15,8))
sns.violinplot(x = data.type, y = data['AveragePrice'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Checking the violinplot of conventional and oraginc avocados to see their average prices.

# %% [markdown]
# ### Avegrage price of organic avocado is more than the average price of conventional avocaods

# %%
f,ax1 = plt.subplots(figsize = (15,8))
sns.boxplot(x = data.region, y = data['AveragePrice'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Box plot of avacodos according to the city they were sold in.

# %%
f,ax1 = plt.subplots(figsize = (15,20))
sns.pointplot(y = data.region, x = data['AveragePrice'], join=True, hue ='type', data= data )
plt.xticks(rotation = 90)
plt.title("Avegrage price in different cities based on type of avocado",{'fontsize':20})
plt.ylabel('City/Region where avocado was sold',{'fontsize' : 'large'})
plt.xlabel('Average Price in USD',{'fontsize':'large'})
plt.show()

# %% [markdown]
# We can confirm that the organic avocado is more expensive in every city, however by different amounts

# %%
f,ax1 = plt.subplots(figsize = (15,20))
sns.pointplot(y = data.region, x = data['AveragePrice'], join=False, hue ='year', data= data )
plt.xticks(rotation = 90)
plt.title("Avegrage price in different cities based on year they were sold",{'fontsize':20})
plt.ylabel('City/Region where avocado was sold',{'fontsize' : 'large'})
plt.xlabel('Average Price in USD',{'fontsize':'large'})
plt.show()

# %% [markdown]
# There is no appreciable price difference trend based on the year the avocado were sold

# %%
data['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# Our dataset is balanced

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x="year", y="AveragePrice", hue='type', data=data)
plt.title("Average price of avocado based on year and type of avocado",{'fontsize':20})
plt.ylabel('Average price in USD',{'fontsize' : 'large'})
plt.xlabel('Year',{'fontsize':'large'})
plt.show()

# %% [markdown]
# It seems like the prices go up and down each year.

# %%
plu = data[['PLU_4046', 'PLU_4225', 'PLU_4770']].groupby(data.year).sum()
plu.plot(kind='line', fontsize = 14, figsize=(14,8))
plt.title("Quantaties of avacodos sold based on PLU",{'fontsize':20})
plt.ylabel('Year',{'fontsize' : 'large'})
plt.xlabel('Quantity sold',{'fontsize':'large'})
# Out:
# Text(0.5, 0, 'Quantity sold')

# %% [markdown]
# ### From the above graph we can observe that PLU 4770 has stayed fairly constant in the quanity sold, however avocados with PLU 4046 and 4225 have dipped in the quantity sold but are still atleast double the quantitu of PLU 4770 sold

# %%
data['Year'], data['Month'],  data['Day'] = data['Date'].str.split('-').str
# Out:
# <ipython-input-21-4a2ab107e6ed>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   data['Year'], data['Month'],  data['Day'] = data['Date'].str.split('-').str

# %% [markdown]
# Here I have splitted the date variable into the year, day and month to get a better understanding of seasonal trends on avocado sales.

# %%
mth = data[['PLU_4046', 'PLU_4225', 'PLU_4770']].groupby(data.Month).sum()
mth.plot(kind='line', fontsize = 14, figsize=(14,8))
plt.title("Quantaties of avacodos sold based on PLU per month",{'fontsize':20})
plt.ylabel('Month',{'fontsize' : 'large'})
plt.xlabel('Quantity sold',{'fontsize':'large'})
# Out:
# Text(0.5, 0, 'Quantity sold')

# %% [markdown]
# Looking at the sale accoding to month of the year.
# More avocados get sold in January and May.

# %%
data.plot(x='Total Volume', y='Total Bags', style='o')
# Out:
# <AxesSubplot:xlabel='Total Volume'>

# %% [markdown]
# Total bags sold compared to total volume sold. As expeced there is a linear coorelation between the two.

# %%
sns.pairplot(data, x_vars=['Small Bags', 'Large Bags', 'XLarge Bags'], y_vars='Total Volume', height=5, aspect=1, kind='reg',diag_kind=None )

# %%
sns.pairplot(data, x_vars=['Small Bags', 'Large Bags', 'XLarge Bags'], y_vars='Total Bags', height=5, aspect=1, kind='reg',diag_kind=None )

# %% [markdown]
# From the above graphs we can interpret that the small bags are sold the most and are in very strong co-relation with Total bags and Total volume.

# %%
binar =[]
for i in data['type']:
    if  i=='conventional':
        binar.append('0')
    elif i=='organic':
        binar.append('1')
data['bin'] = binar

# %% [markdown]
# Converting the types into binary output so our data can be provided to various algorithms.

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  \
# 0           0  2015-12-27          1.33      64236.62   1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98    674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22    794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15   1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60    941.48   43838.39
#
#    PLU_4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0     48.16     8696.87     8603.62       93.25          0.0  conventional
# 1     58.33     9505.56     9408.07       97.49          0.0  conventional
# 2    130.50     8145.35     8042.21      103.14          0.0  conventional
# 3     72.58     5811.16     5677.40      133.76          0.0  conventional
# 4     75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  Year Month Day bin
# ...

# %%
data['PLU_4046'] = data['PLU_4046'].apply(np.ceil)
data['PLU_4046'] = data['PLU_4046'].apply(np.ceil)
data['PLU_4046'] = data['PLU_4046'].apply(np.ceil)
data['PLU_4046'] = data['PLU_4046'].apply(np.ceil)

# %% [markdown]
# Converting the float values to integer values.

# %%
from subprocess import check_output
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn                        import metrics, svm
from sklearn.linear_model           import LogisticRegression
from sklearn import preprocessing
from sklearn import utils

from sklearn import datasets
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import KFold
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import cross_val_score
# Importing required libraries

# %%
X=data[['PLU_4046', 'PLU_4225', 'PLU_4770', 'Small Bags', 'Large Bags', 'XLarge Bags', 'bin']] #feature columns
y=data.AveragePrice #predictor variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

print("X Train Shape ",X_train.shape)
print("Y Train Shape ",y_train.shape)

print("X Test Shape ",X_test.shape)
print("Y Test Shape ",y_test.shape)
# Out:
# X Train Shape  (14599, 7)
# Y Train Shape  (14599,)
# X Test Shape  (3650, 7)
# Y Test Shape  (3650,)

# %% [markdown]
# Splitting out data in 4 parts training to 1 part test. and training our data.

# %% [markdown]
# ### Decesion tree regression

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state=1)
dtr.fit(X_train, y_train)
y_pred = dtr.predict(X_test)
dtr.score(X_test, y_test)
# Out:
# 0.5595198846855334

# %% [markdown]
# ### Random forest regression

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=1)
rfr.fit(X_train, y_train)
y_pred_rfr = rfr.predict(X_test)
rfr.score(X_test, y_test)
# Out:
# 0.7882558063224322

# %% [markdown]
# ### Support vector regression

# %%
from sklearn.svm import SVR
svr = SVR().fit(X_train, y_train)
y_pred_svr = svr.predict(X_test)
svr.score(X_test, y_test)
# Out:
# 0.36415648115855626

# %% [markdown]
# ### Lasso regression

# %%
from sklearn import linear_model
lassoReg = linear_model.Lasso(alpha=0.1).fit(X_train,y_train)

y_pred_lasso = lassoReg.predict(X_test)
lassoReg.score(X_test,y_test)
# Out:
# 0.14019534464839822

# %% [markdown]
# ### Linear regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
lr.score(X_test,y_test)
# Out:
# 0.40054686906798775

# %% [markdown]
# ## Based on the best performance we can conclude that Random Forest Regressor is the best model in our case

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_rfr), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_rfr), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_rfr), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_rfr), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_rfr), 2))
# Out:
# Mean absolute error = 0.13
# Mean squared error = 0.03
# Median absolute error = 0.09
# Explain variance score = 0.79
# R2 score = 0.79

# %% [markdown]
# Check some more metrics for our model

# %% [markdown]
# ### Standardising our data before performing PCA

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X =scaler.fit_transform(X)
X
# Out:
# array([[-0.23081615, -0.1999022 , -0.21209136, ..., -0.22235202,
#         -0.17557961, -0.99983562],
#        [-0.23110232, -0.20805446, -0.21199672, ..., -0.22233464,
#         -0.17557961, -0.99983562],
#        [-0.23100746, -0.1544779 , -0.21132513, ..., -0.22231148,
#         -0.17557961, -0.99983562],
#        ...,
#        [-0.23069361, -0.24309014, -0.20576554, ..., -0.22256082,
#         -0.17557961,  1.00016441],
#        [-0.23042799, -0.24265143, -0.20577419, ..., -0.2225293 ,
#         -0.17557961,  1.00016441],
#        [-0.22934732, -0.24317042, -0.21045012, ..., -0.22262764,
#         -0.17557961,  1.00016441]])

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit_transform(X)
# Out:
# array([[-0.39310279, -1.05575783,  0.05181725, ...,  0.00309659,
#          0.01604798,  0.01189807],
#        [-0.39614719, -1.05595062,  0.05477246, ...,  0.00487636,
#          0.0111392 ,  0.0071955 ],
#        [-0.37406813, -1.05439277,  0.03579721, ..., -0.00633457,
#          0.04577563,  0.03340817],
#        ...,
#        [-0.65639737,  0.9256887 , -0.02004342, ..., -0.00907698,
#         -0.00538737, -0.00389233],
#        [-0.65518888,  0.92583744, -0.02004374, ..., -0.00977901,
#         -0.00470277, -0.00531209],
#        [-0.65621607,  0.92577989, -0.01813004, ..., -0.01306457,
#         -0.00448216, -0.00562316]])

# %%
pca.get_covariance()
# Out:
# array([[ 1.0000548 ,  0.92616071,  0.83343478,  0.92533058,  0.83869097,
#          0.69941561, -0.22583093],
#        [ 0.92616071,  1.0000548 ,  0.88790365,  0.91608143,  0.81005961,
#          0.6888465 , -0.23230212],
#        [ 0.83343478,  0.88790365,  1.0000548 ,  0.80277694,  0.6985093 ,
#          0.67989831, -0.21003882],
#        [ 0.92533058,  0.91608143,  0.80277694,  1.0000548 ,  0.90263833,
#          0.80688884, -0.22054734],
#        [ 0.83869097,  0.81005961,  0.6985093 ,  0.90263833,  1.0000548 ,
#          0.71089737, -0.19318773],
#        [ 0.69941561,  0.6888465 ,  0.67989831,  0.80688884,  0.71089737,
#          1.0000548 , -0.17549272],
#        [-0.22583093, -0.23230212, -0.21003882, -0.22054734, -0.19318773,
#         -0.17549272,  1.0000548 ]])

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.73151   , 0.13383121, 0.05794947, 0.04440415, 0.01773689,
#        0.00941531, 0.00515296])

# %% [markdown]
# ### Plotting the graph for principal component importance

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(7), explained_variance, alpha=0.5, align='center',
            label='individual explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# ### We can see that the first 3 components hold more than 90% of the data, so I will use 3 components.

# %%
pca=PCA(n_components=3)
X_new=pca.fit_transform(X)
X_new
# Out:
# array([[-0.39310279, -1.05575783,  0.05181725],
#        [-0.39614719, -1.05595062,  0.05477246],
#        [-0.37406813, -1.05439277,  0.03579721],
#        ...,
#        [-0.65639737,  0.9256887 , -0.02004342],
#        [-0.65518888,  0.92583744, -0.02004374],
#        [-0.65621607,  0.92577989, -0.01813004]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train.shape
# Out:
# (14599, 7)

# %%
# Establish model
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

# %%
rfr = RandomForestRegressor(random_state=1)
rfr.fit(X_train, y_train)
y_pred_rfr = rfr.predict(X_test)
rfr.score(X_test, y_test)
# Out:
# 0.7884326617933877

# %% [markdown]
# We can see that our score is the same, so PCA didn't cause any depreciation in the results but it reduced our training time.

# %% [markdown]
# ## Using PCA, and using 3 components I have achieved a slightly better score

# %% [markdown]
# ## Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = { 'n_estimators' : [100,150],
               'min_samples_leaf' : [1,2], 
              'min_samples_split': [2,3]
}

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3],
#                          'n_estimators': [100, 150]})

# %%
GCV.best_params_
# Out:
# {'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}

# %% [markdown]
# These are the parameters I'll use to train my model.

# %%
mod = RandomForestRegressor(min_samples_leaf= 1, min_samples_split =2, n_estimators = 100)
mod.fit(X_train,y_train)
pred = mod.predict(X_test)
mod.score(X_test,y_test)
# Out:
# 0.7871969053002655

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(mod,"Avocado.pkl")
# Out:
# ['Avocado.pkl']
